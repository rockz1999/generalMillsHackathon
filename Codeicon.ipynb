# %% [markdown]
# <a href="https://colab.research.google.com/github/rockz1999/generalMillsHackathon/blob/main/Codeicon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/tender_metric_data.csv")
(df.columns)
for i in df.columns:
  if "desc" in i:
    print ("'"+i+"',",end = " ")
# Out:
# 'distribution_channel_desc', 'shp_type_indicator_desc', 'event_action_desc', 'event_type_desc', 'carrier_type_desc', 'shipping_condition_desc', 'temp_condition_desc', 'temp_channel_desc', 'fiscal_month_desc',

# %%
df.drop(['','creation_dt','distribution_channel_desc', 'shp_type_indicator_desc', 'event_action_desc', 'event_type_desc', 'carrier_type_desc', 'shipping_condition_desc', 'temp_condition_desc', 'temp_channel_desc', 'fiscal_month_desc', ], axis=1)
# Out:
#        shipment number  hit_or_miss  ... fiscal_year_week_tag data_flag
# 0             71899922          1.0  ...            F18-WK 45     train
# 1             71899419          1.0  ...            F18-WK 45     train
# 2             71900703          1.0  ...            F18-WK 45     train
# 3             71902024          1.0  ...            F18-WK 45     train
# 4             71901080          1.0  ...            F18-WK 45     train
# ...                ...          ...  ...                  ...       ...
# 99995         72136103          0.0  ...            F19-WK 05     train
# 99996         72143649          1.0  ...            F19-WK 05     train
# 99997         72141767          1.0  ...            F19-WK 05     train
# 99998         72145030          1.0  ...            F19-WK 05     train
# 99999         72146918          1.0  ...            F19-WK 05     train
#
# [100000 rows x 38 columns]

# %%
df.columns
# Out:
# Index(['shipment number', 'hit_or_miss', 'distribution_channel_cd',
#        'distribution_channel_desc', 'shp_type_indicator_fg',
#        'shp_type_indicator_desc', 'transport_group_cd', 'award_carrier_cd',
#        'event_action_cd', 'event_action_desc', 'event_type_cd',
#        'event_type_desc', 'creation_dt', 'creation_ts', 'first_tender_fg',
#        'first_response_fg', 'carrier_type_cd', 'carrier_type_desc',
#        'shipping_condition_cd', 'shipping_condition_desc',
#        'preceding_document_category_cd', 'source_location_cd',
#        'location_from_state_cd', 'destination_location_cd',
#        'location_to_state_cd', 'origin_city_nm', 'destination_city_nm',
#        'origin_country_cd', 'destination_country_cd', 'transport_lane',
#        'source_location_zone_cd', 'destination_location_zone_cd',
#        'source_zip_cd', 'destination_zip_cd', 'transport_region',
#        'freight_order_departure_dt', 'temp_condition_cd',
# ...
